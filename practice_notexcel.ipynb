# %%
import pandas as pd
import numpy as np

df=pd.read_excel('notExercise.xlsx')
df
# Out:
#         기간    대분류            분류  운동을 할 충분한 시간이 없어서 함께 운동을 할 사람이 없어서  \
# 0   2017.0    서울시           NaN               49.7              8.1
# 1      NaN     성별            남자               55.2              7.9
# 2      NaN    NaN            여자               45.0              8.3
# 3      NaN    연령별           10대               55.7              6.1
# 4      NaN    NaN           20대               54.8              6.9
# 5      NaN    NaN           30대               58.1              5.5
# 6      NaN    NaN           40대               57.7              6.8
# 7      NaN    NaN           50대               50.1              9.2
# 8      NaN    NaN        60대 이상               27.5             12.8
# 9      NaN    학력별         중졸 이하               26.1             13.7
# 10     NaN    NaN         고졸 이하               46.3              8.5
# 11     NaN    NaN         대졸 이하               57.4              6.6
# 12     NaN    NaN        대학원 이상               65.3              3.8
# ...

# %%
df.head()
# Out:
#        기간  대분류   분류  운동을 할 충분한 시간이 없어서 함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  \
# 0  2017.0  서울시  NaN               49.7              8.1               5.8
# 1     NaN   성별   남자               55.2              7.9               5.5
# 2     NaN  NaN   여자               45.0              8.3               6.0
# 3     NaN  연령별  10대               55.7              6.1               5.6
# 4     NaN  NaN  20대               54.8              6.9               5.2
#
#    운동을 싫어해서   기타
# 0      34.7  1.7
# 1      29.8  1.6
# 2      38.8  1.8
# 3      32.2  0.3
# 4      32.9  0.1

# %%
df.columns
# Out:
# Index(['기간', '대분류', '분류', '운동을 할 충분한 시간이 없어서', '함께 운동을 할 사람이 없어서',
#        '운동을 할 만한 장소가 없어서', '운동을 싫어해서', '기타'],
#       dtype='object')

# %%
man_woman=[df.values[1][2],df.values[2][2]]

# %%
man_woman
# Out:
# ['남자', '여자']

# %%
type(man_woman)
# Out:
# list

# %%
df.values[1]
# Out:
# array([nan, '성별', '남자', 55.2, 7.9, 5.5, 29.8, 1.6], dtype=object)

# %%
df.values[2]
# Out:
# array([nan, nan, '여자', 45.0, 8.3, 6.0, 38.8, 1.8], dtype=object)

# %%
no_time=[df.values[1][3],df.values[2][3]]

# %%
no_time
# Out:
# [55.2, 45.0]

# %%
type(no_time)
# Out:
# list

# %%
no_one=[df.values[1][4],df.values[2][4]]

# %%
hate_ex=[df.values[1][6],df.values[2][6]]

# %%
no_place=[df.values[1][5],df.values[2][5]]

# %%
import platform
import matplotlib as mpl
from matplotlib import font_manager, rc
system = platform.system()
if system == "Windows":
    font_path = "C:/Windows/Fonts/malgun.ttf"
elif system == "Darwin":
    font_path = "/System/Library/Fonts/AppleSDGothicNeo.ttc"
elif system == "Linux":
    font_path = "/usr/share/fonts/truetype/nanum/NanumGothic.ttf"
else:
    font_path = None
if font_path:
    font = font_manager.FontProperties(fname=font_path).get_name()
    mpl.rcParams['font.family'] = font
else:
    print("폰트 경로를 확인해주세요.")
mpl.rcParams['axes.unicode_minus'] = False

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,8)) 
explode=[0.01,0.01]
plt.subplot(2,2,1)
plt.pie(no_time,labels=man_woman,explode=explode,autopct="%.1f%%")
plt.title('운동을 할 충분한 시간이 없어서')



 
explode=[0.01,0.01]
plt.subplot(2,2,2)
plt.pie(no_one,labels=man_woman,explode=explode,autopct="%.1f%%")
plt.title('함께 운동을 할 사람이 없어서')




explode=[0.01,0.01]
plt.subplot(2,2,3)
plt.pie(hate_ex,labels=man_woman,explode=explode,autopct="%.1f%%")
plt.title('운동을 싫어해서')




explode=[0.01,0.01]
plt.subplot(2,2,4)
plt.pie(no_place,labels=man_woman,explode=explode,autopct="%.1f%%")
plt.title('운동을 할 만한 장소가 없어서')
plt.show()

plt.tight_layout()
plt.show()

# %%
df[3:9]
# Out:
#    기간  대분류      분류  운동을 할 충분한 시간이 없어서 함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  \
# 3 NaN  연령별     10대               55.7              6.1               5.6
# 4 NaN  NaN     20대               54.8              6.9               5.2
# 5 NaN  NaN     30대               58.1              5.5               4.6
# 6 NaN  NaN     40대               57.7              6.8               5.2
# 7 NaN  NaN     50대               50.1              9.2               7.2
# 8 NaN  NaN  60대 이상               27.5             12.8               6.9
#
#    운동을 싫어해서   기타
# 3      32.2  0.3
# 4      32.9  0.1
# 5      31.6  0.2
# 6      29.4    1
# 7      32.2  1.4
# 8      46.8    6

# %%
df_age=df['분류'][3:9]

# %%
df_age=list(df_age.values)

# %%
df_age
# Out:
# ['10대', '20대', '30대', '40대', '50대', '60대 이상']

# %%
df_notime=df['운동을 할 충분한 시간이 없어서'][3:9]

# %%
df_notime=list(df_notime.values)

# %%
df_noone=df['함께 운동을 할 사람이 없어서'][3:9]

# %%
df_noone=list(df['함께 운동을 할 사람이 없어서'][3:9])

# %%
df_noplace=list(df['운동을 할 만한 장소가 없어서'][3:9])

# %%
import matplotlib.pyplot as plt

explode=[0.02,0.02,0.02,0.02,0.02,0.02]
plt.figure(figsize=(12,8))
plt.subplot(1,3,1)
plt.pie(df_notime,labels=df_age,explode=explode,autopct="%.1f%%")
plt.title('운동을 할 충분한 시간이 없어서')



plt.subplot(1,3,2)
explode = [0.02, 0.02, 0.02, 0.02,0.02,0.02]
plt.pie(df_noone,labels=df_age,explode=explode,autopct="%.1f%%")
plt.title('함께 운동을 할 사람이 없어서')

plt.subplot(1,3,3)
explode = [0.02, 0.02, 0.02, 0.02,0.02,0.02]
plt.pie(df_noplace,labels=df_age,explode=explode,autopct="%.1f%%")
plt.title('운동을 할 만한 장소가 없어서')

plt.tight_layout()
plt.show()

# %%
df
# Out:
#         기간    대분류            분류  운동을 할 충분한 시간이 없어서 함께 운동을 할 사람이 없어서  \
# 0   2017.0    서울시           NaN               49.7              8.1
# 1      NaN     성별            남자               55.2              7.9
# 2      NaN    NaN            여자               45.0              8.3
# 3      NaN    연령별           10대               55.7              6.1
# 4      NaN    NaN           20대               54.8              6.9
# 5      NaN    NaN           30대               58.1              5.5
# 6      NaN    NaN           40대               57.7              6.8
# 7      NaN    NaN           50대               50.1              9.2
# 8      NaN    NaN        60대 이상               27.5             12.8
# 9      NaN    학력별         중졸 이하               26.1             13.7
# 10     NaN    NaN         고졸 이하               46.3              8.5
# 11     NaN    NaN         대졸 이하               57.4              6.6
# 12     NaN    NaN        대학원 이상               65.3              3.8
# ...

# %%
df[9:13]
# Out:
#     기간  대분류      분류  운동을 할 충분한 시간이 없어서 함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  \
# 9  NaN  학력별   중졸 이하               26.1             13.7               6.6
# 10 NaN  NaN   고졸 이하               46.3              8.5               6.9
# 11 NaN  NaN   대졸 이하               57.4              6.6               4.9
# 12 NaN  NaN  대학원 이상               65.3              3.8               0.6
#
#     운동을 싫어해서   기타
# 9       46.2  7.4
# 10      36.5  1.7
# 11      30.7  0.4
# 12      29.6  0.6

# %%
edu=list(df['분류'][9:13].values)

# %%
df_notime=list(df['운동을 할 충분한 시간이 없어서'][9:13])

# %%
df_ex_hate=list(df['운동을 싫어해서'][9:13])

# %%
import matplotlib.pyplot as plt
explode = [0.02, 0.02,0.02,0.02]
plt.figure(figsize=(12,8))
plt.subplot(1,2,1)
plt.title('운동을 할 충분한 시간이 없어서')
plt.pie(df_notime,labels=edu,explode=explode,autopct="%.1f%%")

explode = [0.02, 0.02,0.02,0.02]
plt.subplot(1,2,2)
plt.title('운동을 싫어해서')
plt.pie(df_ex_hate,labels=edu,explode=explode,autopct="%.1f%%")
plt.tight_layout()
plt.show()
