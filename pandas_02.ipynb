# %%
import pandas as pd
import numpy as np

KTX_data = {
    '경부선 KTX': [39060, 39896, 42005, 43621, 41702, 41266, 32427],
    '호남선 KTX': [7313, 6967, 6873, 6626, 8675, 10622, 9228],
    '경전선 KTX': [3627, 4168, 4088, 4424, 4606, 4984, 5570],
    '전라선 KTX': [309, 1771, 1954, 2244, 3146, 3945, 5766],
    '동해선 KTX': [np.nan, np.nan, np.nan, np.nan, 2395, 3786, 6667]
}

col_list = ['경부선 KTX', '호남선 KTX', '경전선 KTX', '전라선 KTX', '동해선 KTX']
index_list = ['2011', '2012', '2013', '2014', '2015', '2016', '2017']

df_KTX = pd.DataFrame(KTX_data, columns=col_list, index=index_list)
df_KTX
# Out:
#       경부선 KTX  호남선 KTX  경전선 KTX  전라선 KTX  동해선 KTX
# 2011    39060     7313     3627      309      NaN
# 2012    39896     6967     4168     1771      NaN
# 2013    42005     6873     4088     1954      NaN
# 2014    43621     6626     4424     2244      NaN
# 2015    41702     8675     4606     3146   2395.0
# 2016    41266    10622     4984     3945   3786.0
# 2017    32427     9228     5570     5766   6667.0

# %%
df_KTX.index
# Out:
# Index(['2011', '2012', '2013', '2014', '2015', '2016', '2017'], dtype='object')

# %%
df_KTX.columns
# Out:
# Index(['경부선 KTX', '호남선 KTX', '경전선 KTX', '전라선 KTX', '동해선 KTX'], dtype='object')

# %%
df_KTX.values
# Out:
# array([[39060.,  7313.,  3627.,   309.,    nan],
#        [39896.,  6967.,  4168.,  1771.,    nan],
#        [42005.,  6873.,  4088.,  1954.,    nan],
#        [43621.,  6626.,  4424.,  2244.,    nan],
#        [41702.,  8675.,  4606.,  3146.,  2395.],
#        [41266., 10622.,  4984.,  3945.,  3786.],
#        [32427.,  9228.,  5570.,  5766.,  6667.]])

# %%
df_KTX.head()
# Out:
#       경부선 KTX  호남선 KTX  경전선 KTX  전라선 KTX  동해선 KTX
# 2011    39060     7313     3627      309      NaN
# 2012    39896     6967     4168     1771      NaN
# 2013    42005     6873     4088     1954      NaN
# 2014    43621     6626     4424     2244      NaN
# 2015    41702     8675     4606     3146   2395.0

# %%
df_KTX.tail()
# Out:
#       경부선 KTX  호남선 KTX  경전선 KTX  전라선 KTX  동해선 KTX
# 2013    42005     6873     4088     1954      NaN
# 2014    43621     6626     4424     2244      NaN
# 2015    41702     8675     4606     3146   2395.0
# 2016    41266    10622     4984     3945   3786.0
# 2017    32427     9228     5570     5766   6667.0

# %%
df_KTX.head(3)
# Out:
#       경부선 KTX  호남선 KTX  경전선 KTX  전라선 KTX  동해선 KTX
# 2011    39060     7313     3627      309      NaN
# 2012    39896     6967     4168     1771      NaN
# 2013    42005     6873     4088     1954      NaN

# %%
df_KTX[1:2]
# Out:
#       경부선 KTX  호남선 KTX  경전선 KTX  전라선 KTX  동해선 KTX
# 2012    39896     6967     4168     1771      NaN

# %%
df_KTX[2:5]
# Out:
#       경부선 KTX  호남선 KTX  경전선 KTX  전라선 KTX  동해선 KTX
# 2013    42005     6873     4088     1954      NaN
# 2014    43621     6626     4424     2244      NaN
# 2015    41702     8675     4606     3146   2395.0

# %%
df_KTX.loc['2011']
# Out:
# 경부선 KTX    39060.0
# 호남선 KTX     7313.0
# 경전선 KTX     3627.0
# 전라선 KTX      309.0
# 동해선 KTX        NaN
# Name: 2011, dtype: float64

# %%
df_KTX.loc['2013':'2016']
# Out:
#       경부선 KTX  호남선 KTX  경전선 KTX  전라선 KTX  동해선 KTX
# 2013    42005     6873     4088     1954      NaN
# 2014    43621     6626     4424     2244      NaN
# 2015    41702     8675     4606     3146   2395.0
# 2016    41266    10622     4984     3945   3786.0

# %%
df_KTX['경부선 KTX']
# Out:
# 2011    39060
# 2012    39896
# 2013    42005
# 2014    43621
# 2015    41702
# 2016    41266
# 2017    32427
# Name: 경부선 KTX, dtype: int64

# %%
df_KTX['경부선 KTX']['2012':'2014']
# Out:
# 2012    39896
# 2013    42005
# 2014    43621
# Name: 경부선 KTX, dtype: int64

# %%
df_KTX['경부선 KTX'][2:5]
# Out:
# 2013    42005
# 2014    43621
# 2015    41702
# Name: 경부선 KTX, dtype: int64

# %%
df_KTX['경부선 KTX'][2:5]
# Out:
# 2013    42005
# 2014    43621
# 2015    41702
# Name: 경부선 KTX, dtype: int64

# %%
df_KTX.loc['2016']['호남선 KTX']
# Out:
# np.float64(10622.0)

# %%
df_KTX.loc['2016','호남선 KTX']
# Out:
# np.int64(10622)

# %%
df_KTX['호남선 KTX']['2016']
# Out:
# np.int64(10622)

# %%
df_KTX['호남선 KTX'][5]
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_27052\823467365.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df_KTX['호남선 KTX'][5]
# np.int64(10622)

# %%
df_KTX['호남선 KTX'].loc['2016']
# Out:
# np.int64(10622)

# %%
df_KTX.T
# Out:
#             2011     2012     2013     2014     2015     2016     2017
# 경부선 KTX  39060.0  39896.0  42005.0  43621.0  41702.0  41266.0  32427.0
# 호남선 KTX   7313.0   6967.0   6873.0   6626.0   8675.0  10622.0   9228.0
# 경전선 KTX   3627.0   4168.0   4088.0   4424.0   4606.0   4984.0   5570.0
# 전라선 KTX    309.0   1771.0   1954.0   2244.0   3146.0   3945.0   5766.0
# 동해선 KTX      NaN      NaN      NaN      NaN   2395.0   3786.0   6667.0

# %%
df_KTX[['동해선 KTX','전라선 KTX','경전선 KTX','호남선 KTX','경부선 KTX']]
# Out:
#       동해선 KTX  전라선 KTX  경전선 KTX  호남선 KTX  경부선 KTX
# 2011      NaN      309     3627     7313    39060
# 2012      NaN     1771     4168     6967    39896
# 2013      NaN     1954     4088     6873    42005
# 2014      NaN     2244     4424     6626    43621
# 2015   2395.0     3146     4606     8675    41702
# 2016   3786.0     3945     4984    10622    41266
# 2017   6667.0     5766     5570     9228    32427

# %%
import pandas as pd
import numpy as np

df1=pd.DataFrame({'class1':[95,92,98,200],
                  'class2':[91,93,97,99]})

df1
# Out:
#    class1  class2
# 0      95      91
# 1      92      93
# 2      98      97
# 3     200      99

# %%
df2=pd.DataFrame({'class1':[87,89],
                  'class2':[85,90]})
df2
# Out:
#    class1  class2
# 0      87      85
# 1      89      90

# %%
pd.concat([df1,df2])
# Out:
#    class1  class2
# 0      95      91
# 1      92      93
# 2      98      97
# 3     200      99
# 0      87      85
# 1      89      90

# %%
df3=pd.DataFrame({'Class1':[96,83]})
df3
# Out:
#    Class1
# 0      96
# 1      83

# %%
df4=pd.DataFrame({'Class3':[93,91,95,98]})
df4
# Out:
#    Class3
# 0      93
# 1      91
# 2      95
# 3      98

# %%
df1.join(df4)
# Out:
#    class1  class2  Class3
# 0      95      91      93
# 1      92      93      91
# 2      98      97      95
# 3     200      99      98

# %%
import numpy as np
import pandas as pd


s1=pd.Series([1,2,3,4,5])
s2=pd.Series([10,20,30,40,50])

s1+s2
# Out:
# 0    11
# 1    22
# 2    33
# 3    44
# 4    55
# dtype: int64

# %%
s2-s1
# Out:
# 0     9
# 1    18
# 2    27
# 3    36
# 4    45
# dtype: int64

# %%
s1*s2
# Out:
# 0     10
# 1     40
# 2     90
# 3    160
# 4    250
# dtype: int64

# %%
s2/s1
# Out:
# 0    10.0
# 1    10.0
# 2    10.0
# 3    10.0
# 4    10.0
# dtype: float64

# %%
s3=pd.Series([1,2,3,4])
s4=pd.Series([10,20,30,40])

# %%
s3+s4
# Out:
# 0    11
# 1    22
# 2    33
# 3    44
# dtype: int64

# %%
s4-s3
# Out:
# 0     9
# 1    18
# 2    27
# 3    36
# dtype: int64

# %%
s3*s4
# Out:
# 0     10
# 1     40
# 2     90
# 3    160
# dtype: int64

# %%
s4/s3
# Out:
# 0    10.0
# 1    10.0
# 2    10.0
# 3    10.0
# dtype: float64

# %%
table_data1={'A':[1,2,3,4,5],
             'B':[10,20,30,40,50],
             'C':[100,200,300,400,500]}

df1=pd.DataFrame(table_data1)
df1
# Out:
#    A   B    C
# 0  1  10  100
# 1  2  20  200
# 2  3  30  300
# 3  4  40  400
# 4  5  50  500

# %%
table_data2={'A':[6,7,8],
             'B':[60,70,80],
             'C':[600,700,800]}

df2=pd.DataFrame(table_data2)
df2
# Out:
#    A   B    C
# 0  6  60  600
# 1  7  70  700
# 2  8  80  800

# %%
df1+df2
# Out:
#       A      B       C
# 0   7.0   70.0   700.0
# 1   9.0   90.0   900.0
# 2  11.0  110.0  1100.0
# 3   NaN    NaN     NaN
# 4   NaN    NaN     NaN

# %%
table_data3 = {'봄':  [256.5, 264.3, 215.9, 223.2, 312.8],
              '여름': [770.6, 567.5, 599.8, 387.1, 446.2],
              '가을': [363.5, 231.2, 293.1, 247.7, 381.6],
              '겨울': [139.3, 59.9, 76.9, 109.1, 108.1]}
columns_list = ['봄', '여름', '가을', '겨울']
index_list = ['2012', '2013', '2014', '2015', '2016']

df3=pd.DataFrame(table_data3,columns=columns_list,index=index_list)
df3
# Out:
#           봄     여름     가을     겨울
# 2012  256.5  770.6  363.5  139.3
# 2013  264.3  567.5  231.2   59.9
# 2014  215.9  599.8  293.1   76.9
# 2015  223.2  387.1  247.7  109.1
# 2016  312.8  446.2  381.6  108.1

# %%
df3.mean()
# Out:
# 봄     254.54
# 여름    554.24
# 가을    303.42
# 겨울     98.66
# dtype: float64

# %%
df3.std()
# Out:
# 봄      38.628267
# 여름    148.888895
# 가을     67.358496
# 겨울     30.925523
# dtype: float64

# %%
df3.mean(axis=1)
# Out:
# 2012    382.475
# 2013    280.725
# 2014    296.425
# 2015    241.775
# 2016    312.175
# dtype: float64

# %%
df3.std(axis=1)
# Out:
# 2012    274.472128
# 2013    211.128782
# 2014    221.150739
# 2015    114.166760
# 2016    146.548658
# dtype: float64

# %%
df3.describe()
# Out:
#                 봄          여름          가을          겨울
# count    5.000000    5.000000    5.000000    5.000000
# mean   254.540000  554.240000  303.420000   98.660000
# std     38.628267  148.888895   67.358496   30.925523
# min    215.900000  387.100000  231.200000   59.900000
# 25%    223.200000  446.200000  247.700000   76.900000
# 50%    256.500000  567.500000  293.100000  108.100000
# 75%    264.300000  599.800000  363.500000  109.100000
# max    312.800000  770.600000  381.600000  139.300000

# %%
KTX_data = {'경부선 KTX': [39060, 39896, 42005, 43621, 41702, 41266, 32427],
            '호남선 KTX': [7313, 6967, 6873, 6626, 8675, 10622, 9228],
            '경전선 KTX': [3627, 4168, 4088, 4424, 4606, 4984, 5570],
            '전라선 KTX': [309, 1771, 1954, 2244, 3146, 3945, 5766],
            '동해선 KTX': [np.nan,np.nan, np.nan, np.nan, 2395, 3786, 6667]}
col_list = ['경부선 KTX','호남선 KTX','경전선 KTX','전라선 KTX','동해선 KTX']
index_list = ['2011', '2012', '2013', '2014', '2015', '2016', '2017']



df_KTX=pd.DataFrame(KTX_data,columns=col_list,index=index_list)
df_KTX
# Out:
#       경부선 KTX  호남선 KTX  경전선 KTX  전라선 KTX  동해선 KTX
# 2011    39060     7313     3627      309      NaN
# 2012    39896     6967     4168     1771      NaN
# 2013    42005     6873     4088     1954      NaN
# 2014    43621     6626     4424     2244      NaN
# 2015    41702     8675     4606     3146   2395.0
# 2016    41266    10622     4984     3945   3786.0
# 2017    32427     9228     5570     5766   6667.0

# %%
df_KTX.index
# Out:
# Index(['2011', '2012', '2013', '2014', '2015', '2016', '2017'], dtype='object')

# %%
df_KTX.columns
# Out:
# Index(['경부선 KTX', '호남선 KTX', '경전선 KTX', '전라선 KTX', '동해선 KTX'], dtype='object')

# %%
df_KTX.values
# Out:
# array([[39060.,  7313.,  3627.,   309.,    nan],
#        [39896.,  6967.,  4168.,  1771.,    nan],
#        [42005.,  6873.,  4088.,  1954.,    nan],
#        [43621.,  6626.,  4424.,  2244.,    nan],
#        [41702.,  8675.,  4606.,  3146.,  2395.],
#        [41266., 10622.,  4984.,  3945.,  3786.],
#        [32427.,  9228.,  5570.,  5766.,  6667.]])

# %%
df_KTX.head()
# Out:
#       경부선 KTX  호남선 KTX  경전선 KTX  전라선 KTX  동해선 KTX
# 2011    39060     7313     3627      309      NaN
# 2012    39896     6967     4168     1771      NaN
# 2013    42005     6873     4088     1954      NaN
# 2014    43621     6626     4424     2244      NaN
# 2015    41702     8675     4606     3146   2395.0

# %%
df_KTX.tail()
# Out:
#       경부선 KTX  호남선 KTX  경전선 KTX  전라선 KTX  동해선 KTX
# 2013    42005     6873     4088     1954      NaN
# 2014    43621     6626     4424     2244      NaN
# 2015    41702     8675     4606     3146   2395.0
# 2016    41266    10622     4984     3945   3786.0
# 2017    32427     9228     5570     5766   6667.0

# %%
df_KTX.head(3)
# Out:
#       경부선 KTX  호남선 KTX  경전선 KTX  전라선 KTX  동해선 KTX
# 2011    39060     7313     3627      309      NaN
# 2012    39896     6967     4168     1771      NaN
# 2013    42005     6873     4088     1954      NaN

# %%
df_KTX.tail(2)
# Out:
#       경부선 KTX  호남선 KTX  경전선 KTX  전라선 KTX  동해선 KTX
# 2016    41266    10622     4984     3945   3786.0
# 2017    32427     9228     5570     5766   6667.0

# %%
df_KTX[1:2]
# Out:
#       경부선 KTX  호남선 KTX  경전선 KTX  전라선 KTX  동해선 KTX
# 2012    39896     6967     4168     1771      NaN

# %%
df_KTX[2:5]
# Out:
#       경부선 KTX  호남선 KTX  경전선 KTX  전라선 KTX  동해선 KTX
# 2013    42005     6873     4088     1954      NaN
# 2014    43621     6626     4424     2244      NaN
# 2015    41702     8675     4606     3146   2395.0

# %%
df_KTX.loc['2011']
# Out:
# 경부선 KTX    39060.0
# 호남선 KTX     7313.0
# 경전선 KTX     3627.0
# 전라선 KTX      309.0
# 동해선 KTX        NaN
# Name: 2011, dtype: float64

# %%
df_KTX.loc['2013':'2016']
# Out:
#       경부선 KTX  호남선 KTX  경전선 KTX  전라선 KTX  동해선 KTX
# 2013    42005     6873     4088     1954      NaN
# 2014    43621     6626     4424     2244      NaN
# 2015    41702     8675     4606     3146   2395.0
# 2016    41266    10622     4984     3945   3786.0

# %%
df_KTX['경부선 KTX']
# Out:
# 2011    39060
# 2012    39896
# 2013    42005
# 2014    43621
# 2015    41702
# 2016    41266
# 2017    32427
# Name: 경부선 KTX, dtype: int64

# %%
df_KTX['경부선 KTX']['2012':'2014']
# Out:
# 2012    39896
# 2013    42005
# 2014    43621
# Name: 경부선 KTX, dtype: int64

# %%
df_KTX['경부선 KTX'][2:5]
# Out:
# 2013    42005
# 2014    43621
# 2015    41702
# Name: 경부선 KTX, dtype: int64

# %%
df_KTX.loc['2016']['호남선 KTX']
# Out:
# np.float64(10622.0)

# %%
df_KTX.loc['2016','호남선 KTX']
# Out:
# np.int64(10622)

# %%
df_KTX['호남선 KTX'][5]
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_27052\823467365.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df_KTX['호남선 KTX'][5]
# np.int64(10622)

# %%
df_KTX['호남선 KTX'].loc['2016']
# Out:
# np.int64(10622)

# %%
df_KTX.T
# Out:
#             2011     2012     2013     2014     2015     2016     2017
# 경부선 KTX  39060.0  39896.0  42005.0  43621.0  41702.0  41266.0  32427.0
# 호남선 KTX   7313.0   6967.0   6873.0   6626.0   8675.0  10622.0   9228.0
# 경전선 KTX   3627.0   4168.0   4088.0   4424.0   4606.0   4984.0   5570.0
# 전라선 KTX    309.0   1771.0   1954.0   2244.0   3146.0   3945.0   5766.0
# 동해선 KTX      NaN      NaN      NaN      NaN   2395.0   3786.0   6667.0

# %%
df_KTX[['동해선 KTX','전라선 KTX','경전선 KTX','호남선 KTX','경부선 KTX']]
# Out:
#       동해선 KTX  전라선 KTX  경전선 KTX  호남선 KTX  경부선 KTX
# 2011      NaN      309     3627     7313    39060
# 2012      NaN     1771     4168     6967    39896
# 2013      NaN     1954     4088     6873    42005
# 2014      NaN     2244     4424     6626    43621
# 2015   2395.0     3146     4606     8675    41702
# 2016   3786.0     3945     4984    10622    41266
# 2017   6667.0     5766     5570     9228    32427
