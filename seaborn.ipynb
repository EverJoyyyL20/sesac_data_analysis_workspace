# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings(action='ignore')

# %%
# %%pip install seaborn
# Out:
# UsageError: Cell magic `%%pip` not found (But line magic `%pip` exists, did you mean that instead?).

# %%
import platform
import matplotlib as mpl
from matplotlib import font_manager, rc
system = platform.system()
if system == "Windows":
    font_path = "C:/Windows/Fonts/malgun.ttf"
elif system == "Darwin":
    font_path = "/System/Library/Fonts/AppleSDGothicNeo.ttc"
elif system == "Linux":
    font_path = "/usr/share/fonts/truetype/nanum/NanumGothic.ttf"
else:
    font_path = None
if font_path:
    font = font_manager.FontProperties(fname=font_path).get_name()
    mpl.rcParams['font.family'] = font
else:
    print("폰트 경로를 확인해주세요.")
mpl.rcParams['axes.unicode_minus'] = False

# %%
x=np.linspace(1,14,100)
x
# Out:
# array([ 1.        ,  1.13131313,  1.26262626,  1.39393939,  1.52525253,
#         1.65656566,  1.78787879,  1.91919192,  2.05050505,  2.18181818,
#         2.31313131,  2.44444444,  2.57575758,  2.70707071,  2.83838384,
#         2.96969697,  3.1010101 ,  3.23232323,  3.36363636,  3.49494949,
#         3.62626263,  3.75757576,  3.88888889,  4.02020202,  4.15151515,
#         4.28282828,  4.41414141,  4.54545455,  4.67676768,  4.80808081,
#         4.93939394,  5.07070707,  5.2020202 ,  5.33333333,  5.46464646,
#         5.5959596 ,  5.72727273,  5.85858586,  5.98989899,  6.12121212,
#         6.25252525,  6.38383838,  6.51515152,  6.64646465,  6.77777778,
#         6.90909091,  7.04040404,  7.17171717,  7.3030303 ,  7.43434343,
#         7.56565657,  7.6969697 ,  7.82828283,  7.95959596,  8.09090909,
#         8.22222222,  8.35353535,  8.48484848,  8.61616162,  8.74747475,
#         8.87878788,  9.01010101,  9.14141414,  9.27272727,  9.4040404 ,
# ...

# %%
y1=np.sin(x)
y2=2*np.sin(x)
y3=3*np.sin(x)
y4=4*np.sin(x)

plt.figure(figsize=(10,6))
plt.plot(x,y1,x,y2,x,y3,x,y4)
plt.show()

# %%
import seaborn as sns
import numpy as np
x=np.linspace(1,14,100)
y1=np.sin(x)
y2=2*np.sin(x)
y3=3*np.sin(x)
y4=4*np.sin(x)

sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
plt.plot(x,y1,x,y2,x,y3,x,y4)
plt.show()

# %%
x=np.linspace(1,14,100)
y1=np.sin(x)
y2=2*np.sin(x)
y3=3*np.sin(x)
y4=4*np.sin(x)

sns.set_style('dark')
plt.figure(figsize=(10,6))
plt.plot(x,y1,x,y2,x,y3,x,y4)
plt.show()

# %%
x=np.linspace(1,14,100)
y1=np.sin(x)
y2=2*np.sin(x)
y3=3*np.sin(x)
y4=4*np.sin(x)

sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
plt.plot(x,y1,x,y2,x,y3,x,y4)
sns.despine(right=False,left=False)
plt.show()

# %%
x=np.linspace(1,14,100)
y1=np.sin(x)
y2=2*np.sin(x)
y3=3*np.sin(x)
y4=4*np.sin(x)

sns.set_context('talk')
plt.plot(x,y1,x,y2,x,y3,x,y4)
plt.show()

# %%
sns.set_context('notebook')

# %%
tips=sns.load_dataset('tips')
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.histplot(x=tips['total_bill'])
plt.show()

# %%
sns.kdeplot(x=tips['total_bill'])
plt.show()

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
sns.boxplot(x=tips['total_bill'])
sns.despine()
plt.show()

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(10,6))
sns.boxplot(x=tips['day'],y=tips['total_bill'])
sns.despine(offset=10)
plt.show()

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(10,6))

sns.boxplot(x='day',y='total_bill',data=tips,palette='Set2')
sns.despine(offset=10)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='day',y='tip',hue='smoker',data=tips,palette='Set3')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='day',y='total_bill',hue='sex',data=tips,palette='Set3')
plt.show()

# %%
sns.boxplot(x='day',y='tip',data=tips,palette='Set2')
sns.boxplot(x='day',y='tip',hue='sex',data=tips,palette='Set3')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.boxplot(x='day',y='tip',hue='sex',data=tips,palette='husl')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.swarmplot(x='day',y='total_bill',data=tips,palette='husl')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='day',y='total_bill',data=tips)
sns.swarmplot(x='day',y='total_bill',data=tips,palette='husl')
plt.show()

# %%
sns.set_style('darkgrid')
sns.lmplot(x='total_bill',y='tip',data=tips,height=5)
plt.show()

# %%
import seaborn as sns
sns.lmplot(x='total_bill',y='tip',data=tips,fit_reg=False,height=5)
plt.show()

# %%
sns.lmplot(x='total_bill',y='tip',hue='smoker',data=tips,height=5)
plt.show()

# %%
sns.set_style('darkgrid')
sns.lmplot(x='total_bill',y='tip',hue='sex',data=tips,height=5)
plt.show()

# %%
sns.lmplot(x='total_bill',y='tip',col='sex',data=tips,height=5)
plt.show()

# %%
sns.lmplot(x='total_bill',y='tip',col='smoker',data=tips,height=5)
plt.show()

# %%
uniform_data=np.random.rand(10,12)
uniform_data
# Out:
# array([[0.78120443, 0.32082665, 0.7043317 , 0.31119397, 0.63959585,
#         0.90570111, 0.50072545, 0.76696317, 0.08729575, 0.1121684 ,
#         0.62724488, 0.12953899],
#        [0.47595213, 0.70624203, 0.38495079, 0.8773757 , 0.91245468,
#         0.05524292, 0.82412845, 0.37282533, 0.42132142, 0.17090965,
#         0.36182863, 0.82770703],
#        [0.81766597, 0.82117526, 0.9351385 , 0.27775354, 0.06281318,
#         0.74606498, 0.64496971, 0.47365343, 0.78633477, 0.50871752,
#         0.57305626, 0.53810702],
#        [0.1032446 , 0.90405025, 0.36584471, 0.46350251, 0.3004642 ,
#         0.94494255, 0.55816172, 0.20131695, 0.51697749, 0.79635763,
#         0.71174851, 0.0881416 ],
#        [0.98825816, 0.38095475, 0.85196234, 0.6289986 , 0.53342549,
#         0.65049094, 0.47746351, 0.56260646, 0.8249818 , 0.49337672,
#         0.98502385, 0.2364874 ],
#        [0.44915043, 0.61847082, 0.52843758, 0.89474024, 0.46230691,
# ...

# %%
sns.heatmap(uniform_data,vmin=0,vmax=1)
plt.show()

# %%
tips.corr(numeric_only=True)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
flights=sns.load_dataset("flights")
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights.tail()
# Out:
#      year month  passengers
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432

# %%
flight_p=pd.pivot_table(flights,
                        index='month',
                        columns='year',
                        values='passengers',
                        fill_value=0)
flight_p
# Out:
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
# Jun    135.0  149.0  178.0  218.0  243.0  264.0  315.0  374.0  422.0  435.0
# Jul    148.0  170.0  199.0  230.0  264.0  302.0  364.0  413.0  465.0  491.0
# Aug    148.0  170.0  199.0  242.0  272.0  293.0  347.0  405.0  467.0  505.0
# Sep    136.0  158.0  184.0  209.0  237.0  259.0  312.0  355.0  404.0  404.0
# Oct    119.0  133.0  162.0  191.0  211.0  229.0  274.0  306.0  347.0  359.0
# Nov    104.0  114.0  146.0  172.0  180.0  203.0  237.0  271.0  305.0  310.0
# ...

# %%
# 한글 문제 /
# matplotlib의 기본 폰트에서 한글 지원되지 않기 때문에
# matplotlib의 폰트 변경 필요
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':     # 맥OS
    rc('font', family='AppleGothic')

elif platform.system() == 'Windows':  # 윈도우
    path = "c:/Windows/Fonts/H2GTRM.TTF"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)

# %%
plt.figure(figsize=(10,6))
sns.heatmap(flight_p)
plt.title('연도/월별 승객수')
plt.show()

# %%
plt.figure(figsize=(20,18))
sns.heatmap(flight_p,annot=True,fmt='f')
plt.title("연도/월별 승객수")
plt.show()

# %%
pip install folium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium

# %%
map_osm=folium.Map(location=[45.5236,-122.6750],zoom_start=13)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
map_osm=folium.Map(location=[45.5236,-122.6750],zoom_start=13,tiles='CartoDB positron')
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
map_osm=folium.Map(location=[45.5236,-122.6750],zoom_start=13,tiles='CartoDB positron')

map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
map_1=folium.Map(location=[45.372,-121.6972],zoom_start=11,tiles='OpenStreetMap')

folium.Marker([45.3288,-121.6625],popup='Hood 산',icon=folium.Icon(icon='cloud')).add_to(map_1)

folium.Marker([45.3311,-121.7113],popup='Timberline Lodge',icon=folium.Icon(color='red')).add_to(map_1)

folium.Marker([45.3300,-121.6823],popup='Some other location',icon=folium.Icon(color='green',icon='info-sign')).add_to(map_1)

map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
map_1=folium.Map(location=[37.579617,126.977041],zoom_start=13,tiles='OpenStreetMap')

folium.Marker([37.579617,126.977041],popup='경복궁',icon=folium.Icon(icon='cloud')).add_to(map_1)

map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
import pandas as pd
state_unemployment='02. folium_US_Unemployment_Oct2012.csv'
state_unemp_data=pd.read_csv(state_unemployment)
state_unemp_data.head()
# Out:
#   State  Unemployment
# 0    AL           7.1
# 1    AK           6.8
# 2    AZ           8.1
# 3    AR           7.2
# 4    CA          10.1

# %%
state_geo='02. folium_us-states.json'
state_geo
# Out:
# '02. folium_us-states.json'

# %%
map=folium.Map(location=[40,-98],zoom_start=3)

# %%
map=folium.Map(location=[40,-98],zoom_start=3)

folium.Choropleth(geo_data=state_geo,
                  data=state_unemp_data,
                  columns=['State','Unemployment'],
                  key_on='feature.id',
                  fill_color='YlGn',
                  legend_name='Unemployment Rate(%)').add_to(map)

folium.LayerControl().add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
import json

geo_path='02. skorea_municipalities_geo_simple.json'

geo_str=json.load(open(geo_path,encoding='utf-8'))

# %%
map=folium.Map(location=[37.5502,126.982],
               zoom_start=11,
               tiles='OpenstreetMap')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
f_test=pd.read_csv('cctv_result.csv',encoding='utf-8',index_col='구별')
f_test.head()
# Out:
#        소계       최근증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 구별
# 강남구  3238  150.619195  570500.0  565550.0   4950.0  63167.0  0.867660
# 강동구  1010  166.490765  453233.0  449019.0   4214.0  54622.0  0.929765
# 강북구   831  125.203252  330192.0  326686.0   3506.0  54813.0  1.061806
# 강서구   911  134.793814  603772.0  597248.0   6524.0  72548.0  1.080540
# 관악구  2109  149.290780  525515.0  507203.0  18312.0  68082.0  3.484582
#
#          고령자비율    CCTV비율
# 구별
# 강남구  11.072217  0.567572
# 강동구  12.051638  0.222843
# 강북구  16.600342  0.251672
# 강서구  12.015794  0.150885
# 관악구  12.955291  0.401321

# %%
folium.Choropleth(geo_data=geo_str,
                  data=f_test,
                  columns=[f_test.index,'소계'],
                  key_on='feature.id',
                  fill_color='PuRd',
                  legend_name='CCTV 현황').add_to(map)

folium.LayerControl().add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...
